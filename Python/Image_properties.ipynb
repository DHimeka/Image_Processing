# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
im=cv.imread("aaa.jpeg",cv.IMREAD_COLOR)
im=cv.cvtColor(im,cv.COLOR_BGR2RGB)


fig,ax=plt.subplots()
ax.imshow(im)
ax.set_title("Random Picture")
plt.show()

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
im=cv.imread("aaa.jpeg",cv.IMREAD_GRAYSCALE)
imgb=im+100
imgc=cv.add(im,100)


fig,ax=plt.subplots(1,3)
ax[0].imshow(im,cmap="gray")
ax[0].set_title("Original")
ax[1].imshow(imgb,cmap="gray")
ax[1].set_title("Add 100")
ax[2].imshow(imgc,cmap="gray")
ax[2].set_title("cv.add")
plt.show()

# %%
#increase brightness using Loops
import cv2 as  cv
import numpy as np
import matplotlib.pyplot as plt
def image_brighten(image,shift):
    height,width,channels=image.shape
    for i in range(height):
        for j in range(width):
            for k in range(channels):
                if image[i,j,k]+shift>255:
                    image[i,j,k]=255
                else:
                    image[i,j,k]=image[i,j,k]+shift
    return image
image=cv.imread('aaa.jpeg',cv.IMREAD_GRAYSCALE)
fig,ax=plt.subplots(1,2)
ax[0].imshow(im,cmap="gray")
ax[0].set_title("Original")
ax[1].imshow(imgb,cmap="gray")
ax[1].set_title("image brighten")
# Out:
# Text(0.5, 1.0, 'image brighten')

# %%
import cv2 as cv
import numpy as np
import matplotlib.pyplot as plt
img=cv.imread('laaa.jpeg',cv.IMREAD_ANYCOLOR)
if img is None:
    print("Could not open or find the image")
img=cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img)
plt.title('Original Image')
plt.show()
img[:,:,1:3]=0
plt.imshow(img)
plt.title('Green and Blue channels are zero')
plt.xticks([]) ,plt.yticks([])

plt.show()
# Out:
# Could not open or find the image
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 7
#       5 if img is None:
#       6     print("Could not open or find the image")
# ----> 7 img=cv.cvtColor(img,cv.COLOR_BGR2RGB)
#       8 plt.imshow(img)
#       9 plt.title('Original Image')
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
